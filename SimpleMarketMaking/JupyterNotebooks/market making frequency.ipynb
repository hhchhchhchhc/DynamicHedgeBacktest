# %%
import pandas as pd
tob = pd.read_csv('C:/Users/Tibor/Data/formatted/tobs/20210922_Binance_BTCUSDT_tobs.csv')
tob['spread'] = tob['ask_price'] - tob['bid_price']

# %%
tob.sort_values(by=['spread'], ascending=False)[:10]
# Out:
#          Unnamed: 0  timestamp_millis  bid_price  ask_price  bid_size  \
# 7141410     7141410     1632333770075    4361152    4375311       160
# 7141405     7141405     1632333770073    4361154    4375304       361
# 7141406     7141406     1632333770073    4361154    4375304       361
# 7141407     7141407     1632333770073    4361154    4375304       350
# 813140       813140     1632273434225    4201071    4212389       155
# 7141413     7141413     1632333770075    4365086    4375311       305
# 7141412     7141412     1632333770075    4365086    4375311       306
# 7141411     7141411     1632333770075    4365086    4375311       325
# 7643445     7643445     1632336083545    4343315    4353200     31267
# 7643437     7643437     1632336083544    4343315    4353200     32116
#
#          ask_size  spread
# 7141410      2783   14159
# 7141405         4   14150
# 7141406         3   14150
# 7141407         3   14150
# 813140          1   11318
# 7141413      2783   10225
# ...

# %%
from matplotlib.pyplot import plot
sample = tob[7141400:7141420]
plot(sample['timestamp_millis'], sample['bid_price'])
plot(sample['timestamp_millis'], sample['ask_price'])

# %%
sample = tob[7141400:7141420]
sample
# Out:
#          Unnamed: 0  timestamp_millis  bid_price  ask_price  bid_size  \
# 7141400     7141400     1632333770052    4364753    4365420       217
# 7141401     7141401     1632333770052    4364753    4367308       217
# 7141402     7141402     1632333770052    4366455    4367308         1
# 7141403     7141403     1632333770072    4371000    4375304         7
# 7141404     7141404     1632333770073    4373862    4375304         2
# 7141405     7141405     1632333770073    4361154    4375304       361
# 7141406     7141406     1632333770073    4361154    4375304       361
# 7141407     7141407     1632333770073    4361154    4375304       350
# 7141408     7141408     1632333770073    4361154    4368549       350
# 7141409     7141409     1632333770075    4361152    4368549       160
# 7141410     7141410     1632333770075    4361152    4375311       160
# 7141411     7141411     1632333770075    4365086    4375311       325
# ...

# %%
1630518568306752495-1630518568544462008
# Out:
# -237709513
